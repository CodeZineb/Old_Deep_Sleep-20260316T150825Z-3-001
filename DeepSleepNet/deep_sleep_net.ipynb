# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Old_Deep_Sleep"

# %%
# %ls $path
# Out:
# batch_finetune.sh     evaluate1.py  outputs_finetune/  prepare_physionet.py
# batch_train.sh        evaluate.py   outputs_folds/     summary.py
# deepsleep/            finetune.py   outputs_pretrain/  train.py
# deep_sleep_net.ipynb  model.py      plot.py
# dhedfreader.py        output/       predict.py

# %%
# %cd ../data
# !chmod +x download_physionet.sh

# %%
# !./download_physionet.sh

# %%
# %cd $path
# Out:
# /content/drive/MyDrive/Old_Deep_Sleep

# %%
# %pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 77.8 MB/s eta 0:00:00
# ...

# %%
# !python prepare_physionet.py --data_dir data --output_dir data/eeg_fpz_cz --select_ch 'EEG Fpz-Cz'
# Out:
# /content/drive/MyDrive/research/PSG/DeepSleepNet/tools

# %%
# !python prepare_physionet.py --data_dir data --output_dir data/eeg_pz_oz --select_ch 'EEG Pz-Oz'

# %%
# !pip install tensorflow

# %%
# !python /content/drive/MyDrive/Old_Deep_Sleep/train.py \
  --data_dir /content/drive/MyDrive/DeepSleepNet/PolySomnoGraphy/data/Sleep-EDF/merged_npz_all \
  --output_dir /content/drive/MyDrive/Old_Deep_Sleep/outputs_pretrain \
  --epochs 80 \
  --batch_size 64
# Out:
# 2025-10-28 18:28:26.251185: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761676106.273610   55320 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761676106.280104   55320 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761676106.297884   55320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /content/drive/MyDrive/Old_Deep_Sleep/finetune.py \
  --data_dir /content/drive/MyDrive/DeepSleepNet/PolySomnoGraphy/data/Sleep-EDF/merged_npz_avg \
  --output_dir /content/drive/MyDrive/Old_Deep_Sleep/outputs_finetune \
  --pretrained_model /content/drive/MyDrive/Old_Deep_Sleep/outputs_pretrain/best_model.h5 \
  --epochs 50 \
  --batch_size 64
# Out:
# 2025-10-28 21:46:46.874360: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761688006.894335   13904 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761688006.900306   13904 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761688006.915887   13904 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !chmod +x batch_train.sh

# %%
# !bash batch_train.sh \
/content/drive/MyDrive/DeepSleepNet/PolySomnoGraphy/data/Sleep-EDF/merged_npz_all \
/content/drive/MyDrive/Old_Deep_Sleep/outputs_folds \
0 4 0 80 64
# Out:
# [INFO] Entraînement du fold 0...
# 2025-10-27 21:27:17.978994: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761600437.999900   10970 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761600438.006612   10970 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761600438.023748   10970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !chmod +x batch_finetune.sh

# %%
# !ls -R /content/drive/MyDrive/Old_Deep_Sleep/outputs_pretrain
# Out:
# /content/drive/MyDrive/Old_Deep_Sleep/outputs_pretrain:
# best_model.h5

# %%
# !ls /content/drive/MyDrive/Old_Deep_Sleep/
# Out:
# batch_finetune.sh     dhedfreader.py  outputs_pretrain	    summary.py
# batch_train.sh	      finetune.py     predict.py	    train.py
# deepsleep	      output	      prepare_physionet.py
# deep_sleep_net.ipynb  outputs_folds   results

# %%
# !python3 evaluate.py
# Out:
# 2025-12-01 16:42:52.640266: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764607372.660942    2159 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764607372.667051    2159 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764607372.683302    2159 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python3 evaluate1.py
# Out:
# 2025-12-18 23:36:44.410810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766101004.430484    1778 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766101004.436402    1778 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766101004.451132    1778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python predict.py --data_dir ../DeepSleepNet/PolySomnoGraphy/data/Sleep-EDF/merged_npz_all \
--model_dir output --output_dir output --nbr_subjects 4
# Out:
# 2025-12-01 12:27:09.940751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764592029.959839    3726 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764592029.965724    3726 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764592029.980775    3726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python summary.py --data_dir output
# Out:
# /content/drive/MyDrive/Old_Deep_Sleep/summary.py:40: SyntaxWarning: invalid escape sequence '\d'
#   if re.match("^output_.+\d+\.npz", f):
# (1968,)
# File: output/output_subject0.npz
# Sample: 1968
# W: 371.0
# N1: 117.0
# N2: 623.0
# N3: 517.0
# REM: 340.0
# Confusion matrix:
# [[186  35  49  77  24]
#  [  0   8  75   5  29]
#  [  0   0 470 151   2]
#  [  0   0   6 511   0]
#  [  0   2 194   1 143]]
# Precision: [1.         0.17777778 0.59193957 0.68590605 0.7222222 ]
# Recall: [0.5013477  0.06837607 0.75441414 0.98839456 0.42058823]
# F1: [0.66786355 0.09876543 0.66337335 0.8098256  0.53159845]
# Overall accuracy: 0.6697154471544715
# Macro-F1 accuracy: 0.5542852282524109
# (2289,)
# File: output/output_subject1.npz
# Sample: 2289
# W: 319.0
# N1: 201.0
# N2: 1222.0
# N3: 201.0
# REM: 346.0
# Confusion matrix:
# [[ 138   10   30  123   18]
#  [   4    9   94    5   89]
#  [   0    0 1113   90   19]
#  [   0    0    0  201    0]
#  [   0    0  227    2  117]]
# ...

# %%
# !python plot.py
# Out:
# Figure(1000x500)
# Figure(1000x500)
# Best epoch (from log) = 8
# val_accuracy at best epoch = 0.7491
# val_loss at best epoch = 0.6433
# Saved figures to: /content/drive/MyDrive/Old_Deep_Sleep/plots_deepsleepnet
# Files: loss_curve.png accuracy_curve.png
